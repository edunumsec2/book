# %% [markdown]
# # Activité
#
#
# ## L'exposition d'art contemporain
#
# >**Contenus abordés** : Programmation, introduction aux listes en Python, introduction aux librairies.
#
#
# ***
#
# ### Introduction
#
# Activité d'écriture d'un programme qui génère des présentations absurdes d'artistes contemporains.
#
# ### Objectifs du cours
#
# 1. Comprendre la notion de listes en Python.
# 2. Aborder la notion de librairie (ici : "random.py").
# 3. Exercer des éléments de syntaxe de la fonction "print".
#
#
# ### Matériel requis
#
# **éditeur Python**
#
#
# ### Aller plus loin
#
# On peut varier l'activité sous les angles suivants :
#
# - [ ] Proposer aux élèves de résoudre le problème du *genre* du prompteur automatique par des boucles IF/ELSE.
# - [ ] Proposer aux élèves de modifier les mots à l'intérieur des listes pour rendre le prompteur plus crédible, ou plus absurde.
# - [ ] Proposer aux élèves de créer leur propre générateur de textes aléatoires.
#
# ### Labels
#
# * **Nom (libre)** : L'exposition d'art contemporain
# * **Genre (contraint)** : plugged
# * **Type (contraint)** : activité
# * **Durée (libre)** : en moyenne 90mn (2 périodes)
# * **Thème (contraint / selon plan d'études)** : Introcuction à la programmation
# * **Sujet (contraint / selon plan d'études)** : ?
# * **Outils de mise en place (libre)** : éditeur de Python
# * **Pédagogie (contraint)** : ?
# * **Niveau (contraint)** : moyen
# * **Objectifs info (libre)** :
# 1. Comprendre la notion de listes en Python.
# 2. Aborder la notion de librairie (ici : "random.py").
# 3. Exercer des éléments de syntaxe de la fonction "print".
# * **Objectifs socio (libre)** : ?
# * **Compétences visées (libre)** : analyse, réflexion, créativité, imagination.
# * **Mots-clefs (libre)** : générateur aléatoires, écriture, absurde, humour.
# * **Applications célèbres liées à la ressource (libre)** : ?
# * **Centres d'intérêts (libre)** : art, écriture, poésie, humour, absurde
# * **Auteur(s)**
# * **Relecteur(s)**
# * **Testeur(s)**

# %% [markdown]
# # Le générateur
#
# Maintenant, exécute la cellule suivante. Autant de fois que tu le souhaites.

# %%
from random import choice

prénom = [
'Christopher',
'Ryan',
'Ethan',
'John']

nom = [
'Walker',
'Thompson',
'Anderson',
'Johnson',
'Tremblay',
'Peltier',
'Cunningham',
'Simpson',
'Mercado',
'Sellers']

verbe_1_inf = [
"présenter",
"reconstruire", 
"questionner", 
"interroger",
"juxtaposer",
"rencontrer",
"joindre"]

subst_f_pluriel = [
"les hétérogénéités",
"les consensus",
"les hétérodoxies",
"les masques", 
"les conventions", 
"les subjectivités"]

ville_1 = [
"Bâle",
"Amsterdam",
"Rotterdam",
"Hong-Kong",
"Singapour",
"New-York",
"Lausanne", 
"Genève", 
"Budapest", 
"Zürich",
"Vevey", 
"Montreux", 
"Aigle", 
"Sion", 
"Verbier",
"Martigny"]

subst_medium = [
"la poterie",
"l'alphabet", 
"les monstres", 
"les dinosaures",
"l'anglais", 
"les fabriques de sandales", 
"la guerre", 
"l'art", 
"le mouvement néo-classique",
"le pointillisme",
"l'oeuvre de Van Gogh", 
"la musique viennoise",
"le cinéma expérimental"]

ville_2 = [
"Bâle",
"Amsterdam",
"Rotterdam",
"Hong-Kong",
"Singapour",
"New-York"]

subst_école = [
"Académie de peinture de Poitiers", 
"Ecole des beaux-arts de Nouvelle-Orléans",
"Ecole de guitaire-couture de Londres",
"Académie d'arts appliqués de Boncourt",
"Atelier de design de Porrentruy"]

année = [
"1939",
"1928",
"2002",
"2012"]

verbe_2_conj = [
"transcende",
"peaufine",
"développe",
"affine",
"précise"]

subst_masc_appétence_poss = [
"son goût",
"sa passion",
"son attrait", 
"son désir",
"son attraction",
"son penchant"]

subst_sujetsocio = [
"la lutte des classes",
"l'écologie",
"le climat",
"la montée des eaux",
"la pauvreté dans le tiers-monde",
"les gammes pentatoniques",
"la virtuosité des pinguins"]

verbe_participepassé = [
"marqué",
"caractérisé"]

subst_activitéhumaine = [
"les bacs à sable",
"l'énergie éolienne",
"les courses d'école",
"les sandwichs",
"l'astronomie",
"la mécanique quantique",
"la preuve de l'existence de Dieu",
"la somme théologique de Saint Thomas d'Aquin",
"les dynamiques sociales en milieux urbains",
"l'apprentissage automatique des enfants singes"]

subst_activitéhumaine_2 = [
"l'électricité",
"les conduites d'eau",
"la navigation en eaux troubles",
"les vagues scélérates",
"l'école enfantine", 
"la gymnastique", 
"la marque Coca-Cola",
"la danse classique",
"l'oeuvre de Chopin", 
"les montagnes russes",
"l'extrême-Orient",
"la dilpomatie des mollahs"]

subst_activitéhumaine_3 = [
"les panneaux de signalisation",
"l'exercice physique",
"la gravitation",
"le surpoids",
"le diabète",
"Jean-Jacques Rousseau",
"l'âge d'or de l'école schubertienne",
"les pianos à queue",
"les dîners à la campagne",
"l'oeuvre de Marc Levy"]

verbe_recherche = [
"sonde",
"interroge",
"questionne",
"approfondit",
"met en lumière",
"révèle",
"généralise"]

subst_activitéhumaine_4 = [
"les autotamponeuses dans les milieux défavorisés",
"les jeux sociaux des chimpanzés",
"les stéréotypes de Walt Disney", 
"les biais algorithmiques"]

conjonction_moyen = [
"À travers",
"Grâce à",
"Par l'entremise de"]

subst_objet = [
"cette performance",
"cette installation",
"ce bric-a-brac de génie",
"ce coup d'éclat",
"cette tentative réussie"]

subst_travail_1 = [
"son travail",
"sa production",
"son parcours artistique"]

subst_travail_2 = [
"Son travail"]

qualificatif_importance = [
"urgent",
"impératif",
"important",
"judicieux",
"indispensable"]

verbe_action = [
"réinvestir",
"reconquérir",
"renouveller",
"transformer",
"redécouvrir"]

subst_typeoeuvre = [
"peintures",
"toiles",
"fresques",
"pièces musicales",
"compositions cinématographiques"]

subst_influence = [
"le Bauhaus",
"la Grèce antique",
"Picasso",
"l'impressionisme",
"l'école de Vienne",
"les maîtres flamands",
"le siècle d'or hollandais",
"le pop-art",
"l'Oktoberfest à Munich"]

subst_générique = [
"la géométrie",
"l'automne",
"la vie",
"l'existence", 
"l'enfance", 
"l'imaginaire",
"l'altérité"]

adv_autour = [
"à partir de"]

subst_plusadj = [
"la transcendence"
"l'infini",
"l'au-delà",
"l'appel du vide",
"le dasein"]

verbe_3 = [
"calme",
"revivifie",
"apaise",
"condamne",
"transforme"]

subst_masc_pluriel = [
"les pratiques sociales",
"les émissions de télé-réalité",
"les réseaux sociaux",
"les peuplades affamées",
"les gens idiots",
"les rétrogrades"]

prénom_choisi = choice(prénom)
nom_choisi = choice(nom)

def paragraph1(): 

    return prénom_choisi + " " + nom_choisi + ", " + choice(verbe_1_inf) + " " + choice(subst_f_pluriel) + "."

def paragraph2():

    return "Né à " + choice(ville_1) + " " + prénom_choisi + " " + nom_choisi + " " + "découvre " + choice(subst_medium) + " " + "à" + " " + choice(ville_2) + "." + '\n' + '\n' + choice(subst_travail_2) + " " + "est " + choice(verbe_participepassé) + " par " + choice(subst_activitéhumaine) + " ainsi que par " + choice(subst_activitéhumaine_2) + " et " + choice(subst_activitéhumaine_3) + "." + '\n' +"Diplômé de l’" + choice(subst_école) + " en " + choice (année) + ", " + "il " + choice(verbe_2_conj) + " " + choice(subst_masc_appétence_poss) + " pour " + choice(subst_sujetsocio) + " à " + choice(ville_2) + "."

def paragraph3(): 
    
    return "L'artiste " + prénom_choisi + " " + nom_choisi + " " + choice(verbe_recherche) + " " + "ce qui est induit par " + choice(subst_activitéhumaine_4) + " dans des " + choice(subst_typeoeuvre) + " inspirées par " + choice(subst_influence) + "." + " " + choice(conjonction_moyen) + " " + choice(subst_objet) + "," + " " + choice(subst_travail_1) + " nous rappelle à quel point il est " + choice(qualificatif_importance) + " de " + choice(verbe_action) + " " + choice(subst_générique) + " " + choice(adv_autour) + " " + choice(subst_générique) + ". " + choice(subst_travail_2) + " propose de " + choice(verbe_action) + " " + choice(subst_générique) + " tandis que " + choice(subst_plusadj) + " " + choice(verbe_3) + " " + choice(subst_masc_pluriel) + "." 

print('\n')
print(paragraph1())
print('\n')
print(paragraph2())
print('\n')
print(paragraph3())
print('\n')
# Out:
# Ryan Simpson, juxtaposer les consensus.
#
#
# Né à Martigny Ryan Simpson découvre la poterie à Amsterdam.
#
# Son travail est marqué par l'astronomie ainsi que par la marque Coca-Cola et le diabète.
# Diplômé de l’Académie d'arts appliqués de Boncourt en 1939, il développe son attrait pour l'écologie à Singapour.
#
#
# L'artiste Ryan Simpson met en lumière ce qui est induit par les biais algorithmiques dans des fresques inspirées par le siècle d'or hollandais. À travers cette installation, sa production nous rappelle à quel point il est impératif de renouveller l'enfance à partir de la vie. Son travail propose de réinvestir l'existence tandis que l'appel du vide revivifie les peuplades affamées.

# %% [markdown]
# # Mais ? Comment ça marche ?
#
# ![Alt Text](https://media.giphy.com/media/pPhyAv5t9V8djyRFJH/giphy.gif)
#
# En réalité rien de sorcier. Ce programme, bien qu'il paraisse complexe à première vue, ne fait qu'imprimer des phrases dans lesquelles certains éléments sont choisis aléatoirement à l'intérieur d'une liste prédéfinie.

# %% [markdown]
# # Un texte à trou
#
# Regarde le texte suivant :
#
# > Né à [...], [...][...] découvre [...] à [...].
#
# > Diplômé de l’[...] en [...], il [...] [...] pour [...] à [...]. [...] est [...] par [...] pour [...] ainsi que pour [...]  et [...].
#
# > L'artiste [...] [...] [...] ce qui est induit par [...]. [...] [...], [...] nous rappelle à quel point il est [...] de [...] [...] [...] [...]. [...] propose [...] [...] tandis que [...] [...] [...].
#
# Ca te rappelle quelque chose ?
#
# ![Alt Text](https://media.giphy.com/media/5t9wJjyHAOxvnxcPNk/giphy.gif)
#
# En fait, le programme ci-dessus ne faisait que remplir les trous ([...]) avec des mots choisis au hasard dans des listes.
#
# Une liste en Python, ça ressemble à ça.

# %%
nom_écoles = [
"Académie de peinture de Poitiers", 
"Ecole des beaux-arts de Nouvelle-Orléans",
"Ecole de guitaire-couture",
"Académie d'arts appliqués de Boncourt",
"Atelier de design de Porrentruy"]

années = [
"1939",
"1928",
"2002",
"2012"]

# %% [markdown]
# # Mais encore ?
#
# Maintenant, regarde cette version du texte à trou.
#
# > Né à [ville_1], [prénom][nom] découvre [subst_medium] à [ville_2].
#
# > Diplômé de l’[nom_école] en [année], il [verbe_2_conj] [subst_masc_appétence_poss] pour [subst_sujetsocio] à [ville_2]. [subst_travail_1] est [verbe_participepassé] par [subst_masc_appétence] pour [subst_activitéhumaine] ainsi que pour [subst_activitéhumaine_2]  et [subst_activitéhumaine_3].
#
# > L'artiste [prénom] [nom] [verbe_recherche] ce qui est induit par [subst_activitéhumaine_4]. [conjonction_moyen] [subst_objet], [subst_travail] nous rappelle à quel point il est [qualitifcatif_importance] de [verbe_action] [subst_générique] [adv_autour] [subst_générique]. [subst_travail] propose [verbe_action] [subst_générique] tandis que [subst_adj] [verbe_3] [subst_masculin_pluriel].
#
# ### Heu, où sont passés les [...] ?
#
# Pour que le programme soit capable de comprendre quelle liste on veut placer à quel endroit, il faut que l'on donne des noms précis à chacune de ces listes.
#
# > Note : on peut donner n'importe quel nom à une liste, mais il est important de trouver un nom qui nous permette de retrouver notre liste facilement dans notre programme. Si on appelle "noms_de_pays" une liste qui contient des titres de chansons, on se retrouvera piégé. Ici, les noms des listes correspondent à la fonction grammaticale de l'élément dans la phrase.
